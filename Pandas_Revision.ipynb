# %%
import pandas as pd

# %% [markdown]
# <h3>Creating DataSet</h3>

# %%
data = {
    "Clubs":["FC Barcelona","Juventus FC","Real Madrid","PSG","Man Utd","Man City","Liverpool","Atletico Madrid"],
    "Players":["Lionel Messi","Cristiano Ronaldo","K. Benzema","Neymar Jr","Bruno Fernandes","Kevin De Bruyne","M. Salah","L. Suarez"],
    "Salary(in million $)":[160,121,80,120,85,75,90,82]
}

# %%
players_data = pd.DataFrame(data)
players_data
# Out:
#              Clubs            Players  Salary(in million $)
# 0     FC Barcelona       Lionel Messi                   160
# 1      Juventus FC  Cristiano Ronaldo                   121
# 2      Real Madrid         K. Benzema                    80
# 3              PSG          Neymar Jr                   120
# 4          Man Utd    Bruno Fernandes                    85
# 5         Man City    Kevin De Bruyne                    75
# 6        Liverpool           M. Salah                    90
# 7  Atletico Madrid          L. Suarez                    82

# %% [markdown]
# <h3>Description of Data</h3>

# %%
players_data.loc[0]
# Out:
# Clubs                   FC Barcelona
# Players                 Lionel Messi
# Salary(in million $)             160
# Name: 0, dtype: object

# %%
#display first few Data
players_data.head()
# Out:
#           Clubs            Players  Salary(in million $)
# 0  FC Barcelona       Lionel Messi                   160
# 1   Juventus FC  Cristiano Ronaldo                   121
# 2   Real Madrid         K. Benzema                    80
# 3           PSG          Neymar Jr                   120
# 4       Man Utd    Bruno Fernandes                    85

# %%
#display last few Data
players_data.tail()
# Out:
#              Clubs          Players  Salary(in million $)
# 3              PSG        Neymar Jr                   120
# 4          Man Utd  Bruno Fernandes                    85
# 5         Man City  Kevin De Bruyne                    75
# 6        Liverpool         M. Salah                    90
# 7  Atletico Madrid        L. Suarez                    82

# %%
#Checks if there is any null value
players_data.isnull().sum()
# Out:
# Clubs                   0
# Players                 0
# Salary(in million $)    0
# dtype: int64

# %%
players_data.dtypes
# Out:
# Clubs                   object
# Players                 object
# Salary(in million $)     int64
# dtype: object

# %%
players_data.info
# Out:
# <bound method DataFrame.info of              Clubs            Players  Salary(in million $)
# 0     FC Barcelona       Lionel Messi                   160
# 1      Juventus FC  Cristiano Ronaldo                   121
# 2      Real Madrid         K. Benzema                    80
# 3              PSG          Neymar Jr                   120
# 4          Man Utd    Bruno Fernandes                    85
# 5         Man City    Kevin De Bruyne                    75
# 6        Liverpool           M. Salah                    90
# 7  Atletico Madrid          L. Suarez                    82>

# %%
players_data.describe()
# Out:
#        Salary(in million $)
# count              8.000000
# mean             101.625000
# std               29.505145
# min               75.000000
# 25%               81.500000
# 50%               87.500000
# 75%              120.250000
# max              160.000000

# %%
players_data.shape
# Out:
# (8, 3)

# %% [markdown]
# <h3>Reading from csv</h3>

# %%
titanic_data = pd.read_csv("titanic.csv")
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_data.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_data.shape
# Out:
# (891, 12)

# %%
titanic_data = titanic_data.drop(['Cabin','SibSp','Ticket'],axis=1)
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
titanic_data = titanic_data.fillna(titanic_data['Age'].mean())
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
titanic_data.groupby(['Survived']).size()
# Out:
# Survived
# 0    549
# 1    342
# dtype: int64

# %% [markdown]
# <h3>Reading from excel</h3>

# %%
canadafuel_data = pd.read_excel("canadafuel.xlsx")
canadafuel_data
# Out:
#      Year   MAKE           MODEL             VEHICLE CLASS  ENGINE SIZE  \
# 0    2000  ACURA           1.6EL                   COMPACT          1.6
# 1    2000  ACURA           1.6EL                   COMPACT          1.6
# 2    2000  ACURA           3.2TL                  MID-SIZE          3.2
# 3    2000  ACURA           3.5RL                  MID-SIZE          3.5
# 4    2000  ACURA         INTEGRA                SUBCOMPACT          1.8
# ..    ...    ...             ...                       ...          ...
# 634  2000  VOLVO   V70 AWD TURBO  STATION WAGON - MID-SIZE          2.4
# 635  2000  VOLVO   V70 GLT TURBO  STATION WAGON - MID-SIZE          2.4
# 636  2000  VOLVO    V70 T5 TURBO  STATION WAGON - MID-SIZE          2.3
# 637  2000  VOLVO    V70 T5 TURBO  STATION WAGON - MID-SIZE          2.3
# 638  2000  VOLVO  V70R AWD TURBO  STATION WAGON - MID-SIZE          2.4
#
#      CYLINDERS TRANSMISSION FUEL  FUEL CONSUMPTION   CO
# ...

# %% [markdown]
# <h3>Reading from json</h3>

# %%
data1 = pd.read_json('intents.json')
data1
# Out:
#                                              intents
# 0  {'tag': 'greeting', 'pattern': ['Hello', 'Hey ...
# 1  {'tag': 'goodbye', 'pattern': ['Bye', 'GoodBye...
# 2  {'tag': 'symptoms', 'pattern': ['What are the ...
# 3  {'tag': 'precautions', 'pattern': ['What are t...
# 4  {'tag': 'treatment', 'pattern': ['What are the...
# 5  {'tag': 'quarantine_period', 'pattern': ['What...
# 6  {'tag': 'risk', 'pattern': ['Who are at risk o...
# 7  {'tag': 'spread', 'pattern': ['How is the coro...
